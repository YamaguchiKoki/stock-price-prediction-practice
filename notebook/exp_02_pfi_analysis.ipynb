# %%
import sys
from pathlib import Path

# ベースラインモデルとして、時系列順に8:2で分割して学習データと検証データを作成し、勾配ブースティング木モデルのスコアを記録する
# プロジェクトルートのパスを通す
sys.path.append(str(Path.cwd().parent))

# %%
import pandas as pd
from src.features.feature_engineering import create_features
from src.utils.env import EnvConfig


config = EnvConfig()
train_data_path = config.abs_input_dir / 'train.csv'
test_data_path = config.abs_input_dir / 'test.csv'

df_raw = pd.read_csv(train_data_path)
df_feat = create_features(df_raw)

df_feat.head()
# Out:
#              Open   High    Low  Close  Up  dayofweek  Open_lag_1  \
# Date
# 2004-01-15  51.01  51.27  50.70  51.01   1          3       50.43
# 2004-01-16  50.97  51.16  50.89  51.13   1          4       51.01
# 2004-01-20  51.40  51.46  51.04  51.21   0          1       50.97
# 2004-01-21  50.94  51.18  50.86  51.10   1          2       51.40
# 2004-01-22  51.19  51.41  51.14  51.20   0          3       50.94
#
#             Open_diff_1  Open_lag_2  Open_diff_2  ...  close_max_5  \
# Date                                              ...
# 2004-01-15         0.58       50.90         0.11  ...        51.01
# 2004-01-16        -0.04       50.43         0.54  ...        51.13
# 2004-01-20         0.43       51.01         0.39  ...        51.21
# 2004-01-21        -0.46       50.97        -0.03  ...        51.21
# 2004-01-22         0.25       51.40        -0.21  ...        51.21
#
#             close_min_5  close_range_5  close_ma_10  close_std_10  \
# Date
# 2004-01-15        50.61           0.40       50.959      0.291641
# 2004-01-16        50.61           0.52       51.000      0.283000
# 2004-01-20        50.61           0.60       51.042      0.279515
# 2004-01-21        50.64           0.57       51.037      0.277811
# 2004-01-22        51.01           0.20       51.006      0.232818
#
#             close_max_10  close_min_10  close_range_10  close_up  streak
# Date
# 2004-01-15         51.51         50.61            0.90         1       2
# 2004-01-16         51.51         50.61            0.90         1       3
# 2004-01-20         51.51         50.61            0.90         1       4
# 2004-01-21         51.51         50.61            0.90         0      -1
# 2004-01-22         51.28         50.61            0.67         1       1
#
# [5 rows x 50 columns]

# %%
from src.models.model_xgb import ModelXGB
from src.metrics import classification_metrics
from hydra import initialize, compose
from hydra.core.global_hydra import GlobalHydra
from omegaconf import OmegaConf
from sklearn.model_selection import train_test_split
from src.analysis.pfi_analyzer import PFIAnalyzer
from xgboost import XGBClassifier

X = df_feat.drop(columns=['Up'])
y = df_feat['Up']

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, shuffle=False)

if GlobalHydra.instance().is_initialized():
    GlobalHydra.instance().clear()


# ========= Hydra config 読み込み ========= #
initialize(config_path="../configs", version_base="1.3")
cfg = compose(config_name="config")
print("\u2705 Loaded config:\n", OmegaConf.to_yaml(cfg))

params = dict(cfg.model)
num_round = params.pop('num_round')
early_stopping_rounds = params.pop('early_stopping_rounds')

# ========= XGBoost モデルの初期化(scikit-learnのAPIに準拠させるため自作のラッパークラスは使わない) ========= #
clf = XGBClassifier(params={
    **params,
    "early_stopping_rounds": early_stopping_rounds,
    "num_round": num_round
})
clf.fit(X_train, y_train)

# ========= PFI 分析 ========= #
pfi = PFIAnalyzer(clf, X_val, y_val)
pfi.compute()
pfi.plot(top_n=20)
# Out:
# /Users/kokiyamaguchi/Documents/projects/competitions/stock-prediction-practice/.venv/lib/python3.13/site-packages/hydra/_internal/defaults_list.py:251: UserWarning: In 'config': Defaults list is missing `_self_`. See https://hydra.cc/docs/1.2/upgrades/1.0_to_1.1/default_composition_order for more information
#   warnings.warn(msg, UserWarning)
# /Users/kokiyamaguchi/Documents/projects/competitions/stock-prediction-practice/.venv/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [22:15:45] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "params" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# ✅ Loaded config:
#  model:
#   name: xgb
#   objective: binary:logistic
#   eval_metric: logloss
#   eta: 0.1
#   max_depth: 3
#   subsample: 0.8
#   colsample_bytree: 0.8
#   early_stopping_rounds: 50
#   num_round: 1000
# seed: 42
# target_col: Up
